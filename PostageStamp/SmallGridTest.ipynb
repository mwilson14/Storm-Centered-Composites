# %%
from stamp_track_framework import multi_case_algorithm_2020
#from spork_framework_2020_loc import multi_case_algorithm_2020_loc
#from ridiculous_framework_devSPINLOCAL import multi_case_algorithm_ML1_devSPINLOCAL

import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import pickle
from netCDF4 import Dataset
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
#REFall, ZDRall, KDPall, CCall, NORM_ZDR, az_masked, rlons_2d, rlats_2d = multi_case_algorithm_2020(2016, 3, 16, 0, 39, 0.05, 0.0, 'KILX', -89.85, 39.722)

#REFall, ZDRall, KDPall, CCall, NORM_ZDR, az_masked, rlons_2d, rlats_2d = multi_case_algorithm_2020(2019, 6, 9, 1, 9, 0.10, 0.0, 'KGLD', -101.51, 39.27, 3500, 140)

#REFall, ZDRall, KDPall, CCall, NORM_ZDR, az_masked, rlons_2d, rlats_2d = multi_case_algorithm_2020(2023, 5, 12, 23, 29, 0.10, 0.0, 'KOAX', -96.64, 41.54, 3500, 140)

#REFall, ZDRall, KDPall, CCall, NORM_ZDR, az_masked, rlons_2d, rlats_2d = multi_case_algorithm_2020(2014, 4, 25, 23, 35, 0.10, 0.0, 'KMHX', -77.12, 35.51, 3500, 140)

#REFall, ZDRall, KDPall, CCall, NORM_ZDR, az_masked, rlons_2d, rlats_2d = multi_case_algorithm_2020(2016, 5, 22, 23, 13, 0.10, 0.0, 'KMAF', -101.64, 32.25, 3500, 140)

#REFall, ZDRall, KDPall, CCall, NORM_ZDR, az_masked, rlons_2d, rlats_2d = multi_case_algorithm_2020(2018, 12, 18, 21, 50, 0.10, 0.0, 'KATX', -122.639, 47.507, 3500, 140)

#REFall, ZDRall, KDPall, CCall, NORM_ZDR, az_masked, rlons_2d, rlats_2d = multi_case_algorithm_2020(2023, 4, 1, 3, 33, 0.10, 0.0, 'KIND', -86.1, 39.54, 3500, 140)

#REFall, ZDRall, KDPall, CCall, NORM_ZDR, az_masked, rlons_2d, rlats_2d = multi_case_algorithm_2020(2014, 7, 27, 21, 58, 0.10, 0.0, 'KMRX', -83.98, 36.47, 3500, 140)

REFall, ZDRall, KDPall, CCall, NORM_ZDR, az_masked, rlons_2d, rlats_2d = multi_case_algorithm_2020(2015, 12, 23, 22, 10, 0.10, 0.0, 'KNQA', -89.71, 34.60, 3500, 140)
# Out:
# Downloaded KNQA20151223_221225_V06.gz
# 1 out of 1 files downloaded...0 errors
# File Reading
# Pre-grid Organization Section
# 0.5141716
# bad split cut
# 0.5378647
# 0.93131256
# bad split cut
# 0.9308777
# 1.3512535
# bad split cut
# 1.3712997
# 1.8555603
# 2.4457169
# 3.1766663
# 0.5034485
# bad split cut
# 0.5379982
# 4.057892
# 5.112625
# 6.4378357
# 8.039847
# 10.083656
# 12.538597
# 15.664017
# 19.546692
# KDP Section
# Grid Section
# 60.362457
# -89.87333679199219 35.344722747802734
# No file yet...
# No file yet...
# We have the file we need3!
# ...

# %%
print(np.nanmax(REF))

# %%
print(REF.shape)

# %%
print(az_masked)
